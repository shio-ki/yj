# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import lib.const as const 
import lib.mhys as mhys
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
raw_number = mhys.qg()
mhp = mhys.pan(raw_number)
mhp_cn = mhys.convert_to_chinese(mhp)
sign_df = mhys.show_sign(mhp)
display(mhp_cn)
display(sign_df)
# Out:
#                         本卦                  互卦                  变卦 数字起卦
# 上卦                 8 坤 (地)             4 震 (雷)             7 艮 (山)   32
# 下卦                 1 乾 (天)             2 兑 (泽)             1 乾 (天)   25
# 变爻                       6                                           60
# 五行生克           (土) 体生用 (金)                             (土) 体生用 (金)
# 上卦（五行）               土 (用)               木 (用)               土 (用)
# 下卦（五行）               金 (体)               金 (体)               金 (体)
# 上卦*              (0, 0, 0)           (0, 0, 1)           (1, 0, 0)
# 下卦*              (1, 1, 1)           (0, 1, 1)           (1, 1, 1)
# 卦       (0, 0, 0, 1, 1, 1)  (0, 0, 1, 0, 1, 1)  (1, 0, 0, 1, 1, 1)
#          本卦       互卦       变卦
# 上爻  ___ ___  ___ ___  _______
# 五爻  ___ ___  ___ ___  ___ ___
# 四爻  ___ ___  _______  ___ ___
# 三爻  _______  ___ ___  _______
# 二爻  _______  _______  _______
# 初爻  _______  _______  _______
